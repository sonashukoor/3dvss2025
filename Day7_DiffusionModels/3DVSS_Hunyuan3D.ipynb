# %% [markdown]
# # Image-2-3D using Hunyuan3D 2.0
#
# ---
#
# - Project Page: https://www.hunyuan-3d.com/
# - HuggingFace: https://huggingface.co/spaces/tencent/Hunyuan3D-2

# %% [markdown]
# ## 1) Dependencies

# %%
# !git clone https://github.com/Tencent-Hunyuan/Hunyuan3D-2.git
# Out:
# Cloning into 'Hunyuan3D-2'...
# remote: Enumerating objects: 1043, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 1043 (delta 11), reused 3 (delta 3), pack-reused 1022 (from 3)
# Receiving objects: 100% (1043/1043), 81.26 MiB | 20.73 MiB/s, done.
# Resolving deltas: 100% (485/485), done.

# %%
# %cd Hunyuan3D-2
# !pip install -e .
# %cd hy3dgen/texgen/custom_rasterizer
# !python3 setup.py install
# %cd ../../..
# %cd hy3dgen/texgen/differentiable_renderer
# !python3 setup.py install
# %cd ../../..
# Out:
# /content/Hunyuan3D-2
# Obtaining file:///content/Hunyuan3D-2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gradio in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (5.31.0)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (2.0.2)
# Collecting ninja (from hy3dgen==2.0.2)
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (0.34.0)
# Collecting pybind11 (from hy3dgen==2.0.2)
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (4.11.0.86)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (0.8.1)
# Requirement already satisfied: transformers>=4.48.0 in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (4.52.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (2.3.0)
# Collecting trimesh (from hy3dgen==2.0.2)
#   Downloading trimesh-4.6.13-py3-none-any.whl.metadata (18 kB)
# Collecting pymeshlab (from hy3dgen==2.0.2)
#   Downloading pymeshlab-2023.12.post3-cp311-cp311-manylinux_2_31_x86_64.whl.metadata (3.7 kB)
# Collecting pygltflib (from hy3dgen==2.0.2)
#   Downloading pygltflib-1.16.4-py3-none-any.whl.metadata (33 kB)
# Collecting xatlas (from hy3dgen==2.0.2)
#   Downloading xatlas-0.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (1.8.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (0.115.13)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from hy3dgen==2.0.2) (0.34.3)
# Collecting rembg (from hy3dgen==2.0.2)
#   Downloading rembg-2.0.66-py3-none-any.whl.metadata (21 kB)
# Collecting onnxruntime (from hy3dgen==2.0.2)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (0.33.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->hy3dgen==2.0.2) (0.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->hy3dgen==2.0.2) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->hy3dgen==2.0.2) (2.6.0+cu124)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from diffusers->hy3dgen==2.0.2) (8.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers->hy3dgen==2.0.2) (11.2.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->hy3dgen==2.0.2) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi->hy3dgen==2.0.2) (2.11.7)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->hy3dgen==2.0.2) (4.14.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (4.9.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.1 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (1.10.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (3.10.18)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (2.2.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.12.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio->hy3dgen==2.0.2) (0.16.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio->hy3dgen==2.0.2) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio->hy3dgen==2.0.2) (15.0.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->hy3dgen==2.0.2) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->hy3dgen==2.0.2) (0.16.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->hy3dgen==2.0.2) (4.9.3)
# Collecting coloredlogs (from onnxruntime->hy3dgen==2.0.2)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->hy3dgen==2.0.2) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime->hy3dgen==2.0.2) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime->hy3dgen==2.0.2) (1.13.1)
# Collecting dataclasses-json>=0.0.25 (from pygltflib->hy3dgen==2.0.2)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated (from pygltflib->hy3dgen==2.0.2)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from rembg->hy3dgen==2.0.2) (4.24.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from rembg->hy3dgen==2.0.2) (4.11.0.86)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/dist-packages (from rembg->hy3dgen==2.0.2) (1.8.2)
# Collecting pymatting (from rembg->hy3dgen==2.0.2)
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from rembg->hy3dgen==2.0.2) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from rembg->hy3dgen==2.0.2) (1.15.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio->hy3dgen==2.0.2) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio->hy3dgen==2.0.2) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib->hy3dgen==2.0.2)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib->hy3dgen==2.0.2)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio->hy3dgen==2.0.2) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio->hy3dgen==2.0.2) (1.0.9)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.48.0->hy3dgen==2.0.2) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->hy3dgen==2.0.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->hy3dgen==2.0.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->hy3dgen==2.0.2) (0.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (3.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate->hy3dgen==2.0.2)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hy3dgen==2.0.2) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime->hy3dgen==2.0.2) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (13.9.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->hy3dgen==2.0.2)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->pygltflib->hy3dgen==2.0.2) (1.17.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->diffusers->hy3dgen==2.0.2) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->rembg->hy3dgen==2.0.2) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->rembg->hy3dgen==2.0.2) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->rembg->hy3dgen==2.0.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->rembg->hy3dgen==2.0.2) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch->rembg->hy3dgen==2.0.2) (4.3.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.48.0->hy3dgen==2.0.2) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.48.0->hy3dgen==2.0.2) (2.4.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.11/dist-packages (from pymatting->rembg->hy3dgen==2.0.2) (0.60.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->rembg->hy3dgen==2.0.2) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->rembg->hy3dgen==2.0.2) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->rembg->hy3dgen==2.0.2) (0.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba!=0.49.0->pymatting->rembg->hy3dgen==2.0.2) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->hy3dgen==2.0.2) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (2.19.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->hy3dgen==2.0.2)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->hy3dgen==2.0.2) (0.1.2)
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 15.8 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 89.5 MB/s eta 0:00:00
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 22.5 MB/s eta 0:00:00
# Downloading pygltflib-1.16.4-py3-none-any.whl (27 kB)
# Downloading pymeshlab-2023.12.post3-cp311-cp311-manylinux_2_31_x86_64.whl (98.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 9.2 MB/s eta 0:00:00
# Downloading rembg-2.0.66-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.7 MB/s eta 0:00:00
# Downloading trimesh-4.6.13-py3-none-any.whl (712 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 712.4/712.4 kB 51.3 MB/s eta 0:00:00
# Downloading xatlas-0.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.1/239.1 kB 23.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.5 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.6 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.9 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: xatlas, trimesh, pymeshlab, pybind11, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ninja, mypy-extensions, marshmallow, humanfriendly, deprecated, typing-inspect, pymatting, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, onnxruntime, nvidia-cusolver-cu12, dataclasses-json, rembg, pygltflib, hy3dgen
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Running setup.py develop for hy3dgen
# Successfully installed coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.18 humanfriendly-10.0 hy3dgen-2.0.2 marshmallow-3.26.1 mypy-extensions-1.1.0 ninja-1.11.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnxruntime-1.22.0 pybind11-2.13.6 pygltflib-1.16.4 pymatting-1.1.14 pymeshlab-2023.12.post3 rembg-2.0.66 trimesh-4.6.13 typing-inspect-0.9.0 xatlas-0.0.10
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating custom_rasterizer.egg-info
# writing custom_rasterizer.egg-info/PKG-INFO
# writing dependency_links to custom_rasterizer.egg-info/dependency_links.txt
# writing top-level names to custom_rasterizer.egg-info/top_level.txt
# writing manifest file 'custom_rasterizer.egg-info/SOURCES.txt'
# reading manifest file 'custom_rasterizer.egg-info/SOURCES.txt'
# writing manifest file 'custom_rasterizer.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib.linux-x86_64-cpython-311/custom_rasterizer
# copying ./custom_rasterizer/io_glb.py -> build/lib.linux-x86_64-cpython-311/custom_rasterizer
# copying ./custom_rasterizer/__init__.py -> build/lib.linux-x86_64-cpython-311/custom_rasterizer
# copying ./custom_rasterizer/render.py -> build/lib.linux-x86_64-cpython-311/custom_rasterizer
# copying ./custom_rasterizer/io_obj.py -> build/lib.linux-x86_64-cpython-311/custom_rasterizer
# running build_ext
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:448: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.4). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:458: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'custom_rasterizer_kernel' extension
# creating /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Emitting ninja build file /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] c++ -MMD -MF /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/rasterizer.o.d -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c -c /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer.cpp -o /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/rasterizer.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=custom_rasterizer_kernel -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer.cpp: In function ‘void rasterizeTriangleCPU(int, float*, float*, float*, int, int, long long unsigned int*, float*, float)’:
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer.cpp:15:31: warning: narrowing conversion of ‘((double)px + 5.0e-1)’ from ‘double’ to ‘float’ [-Wnarrowing]
#    15 |             float vt[2] = {px + 0.5, py + 0.5};
#       |                            ~~~^~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer.cpp:15:41: warning: narrowing conversion of ‘((double)py + 5.0e-1)’ from ‘double’ to ‘float’ [-Wnarrowing]
#    15 |             float vt[2] = {px + 0.5, py + 0.5};
#       |                                      ~~~^~~~~
# [2/3] c++ -MMD -MF /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/grid_neighbor.o.d -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c -c /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp -o /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/grid_neighbor.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=custom_rasterizer_kernel -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp: In function ‘void DownsampleGrid(Grid&, Grid&)’:
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:164:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   164 |     for (int i = 0; i < src.seq2grid.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:182:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   182 |     for (int i = 0; i < seq2normal_count.size(); i += 3) {
#       |                     ~~^~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp: In function ‘void NeighborGrid(Grid&, std::vector<at::Tensor>, int)’:
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:203:13: warning: unused variable ‘num_view_layers’ [-Wunused-variable]
#   203 |         int num_view_layers = t0.size(0);
#       |             ^~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp: In function ‘void PadGrid(Grid&, Grid&, std::vector<at::Tensor>&)’:
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:271:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   271 |     for (int i = 0; i < downsample_seq.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:281:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   281 |     for (int i = 0; i < tar_seq2grid.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp: In function ‘std::vector<std::vector<at::Tensor> > build_hierarchy(std::vector<at::Tensor>, std::vector<at::Tensor>, int, int)’:
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:315:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘std::vector<at::Tensor>::size_type’ {aka ‘long unsigned int’} [-Wformat=]
#   315 |         printf("Alert! We require 3 layers and at least 1 level! (%d %d)\n", view_layer_positions.size(), num_level);
#       |                                                                   ~^         ~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       |                                                                    |                                  |
#       |                                                                    int                                std::vector<at::Tensor>::size_type {aka long unsigned int}
#       |                                                                   %ld
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:382:45: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   382 |     for (int i = grids[0].num_origin_seq; i < grids[0].seq2grid.size(); ++i) {
#       |                                           ~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:402:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   402 |     for (int i = 0; i < grids[0].seq2grid.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:406:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Grid>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   406 |     for (int i = 0; i < grids.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:409:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   409 |         for (int j = 0; j < grids[i].seq2neighbor.size(); ++j) {
#       |                         ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:416:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   416 |         for (int j = 0; j < grids[i].seq2evencorner.size(); ++j) {
#       |                         ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:420:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   420 |         for (int j = 0; j < grids[i].seq2oddcorner.size(); ++j) {
#       |                         ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:423:19: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Grid>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   423 |         if (i + 1 < grids.size()) {
#       |             ~~~~~~^~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:426:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   426 |             for (int j = 0; j < grids[i].downsample_seq.size(); ++j) {
#       |                             ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp: In function ‘std::vector<std::vector<at::Tensor> > build_hierarchy_with_feat(std::vector<at::Tensor>, std::vector<at::Tensor>, std::vector<at::Tensor>, int, int)’:
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:442:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘std::vector<at::Tensor>::size_type’ {aka ‘long unsigned int’} [-Wformat=]
#   442 |         printf("Alert! We require 3 layers and at least 1 level! (%d %d)\n", view_layer_positions.size(), num_level);
#       |                                                                   ~^         ~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       |                                                                    |                                  |
#       |                                                                    int                                std::vector<at::Tensor>::size_type {aka long unsigned int}
#       |                                                                   %ld
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:518:45: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   518 |     for (int i = grids[0].num_origin_seq; i < grids[0].seq2grid.size(); ++i) {
#       |                                           ~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:543:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   543 |     for (int i = 0; i < grids[0].seq2grid.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:549:23: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Grid>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   549 |     for (int i = 0; i < grids.size(); ++i) {
#       |                     ~~^~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:552:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   552 |         for (int j = 0; j < grids[i].seq2neighbor.size(); ++j) {
#       |                         ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:558:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   558 |         for (int j = 0; j < grids[i].seq2evencorner.size(); ++j) {
#       |                         ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:562:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   562 |         for (int j = 0; j < grids[i].seq2oddcorner.size(); ++j) {
#       |                         ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:565:19: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Grid>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   565 |         if (i + 1 < grids.size()) {
#       |             ~~~~~~^~~~~~~~~~~~~~
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/grid_neighbor.cpp:568:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<int>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   568 |             for (int j = 0; j < grids[i].downsample_seq.size(); ++j) {
#       |                             ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [3/3] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/rasterizer_gpu.o.d -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c -c /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer_gpu.cu -o /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/rasterizer_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=custom_rasterizer_kernel -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer_gpu.cu(57): warning #186-D: pointless comparison of unsigned integer with zero
#       if (f >= 0) {
#             ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/lib/custom_rasterizer_kernel/rasterizer_gpu.cu(57): warning #186-D: pointless comparison of unsigned integer with zero
#       if (f >= 0) {
#             ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/grid_neighbor.o /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/rasterizer.o /content/Hunyuan3D-2/hy3dgen/texgen/custom_rasterizer/build/temp.linux-x86_64-cpython-311/lib/custom_rasterizer_kernel/rasterizer_gpu.o -L/usr/local/lib/python3.11/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-311/custom_rasterizer_kernel.cpython-311-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-311/custom_rasterizer_kernel.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/custom_rasterizer
# copying build/lib.linux-x86_64-cpython-311/custom_rasterizer/io_glb.py -> build/bdist.linux-x86_64/egg/custom_rasterizer
# copying build/lib.linux-x86_64-cpython-311/custom_rasterizer/__init__.py -> build/bdist.linux-x86_64/egg/custom_rasterizer
# copying build/lib.linux-x86_64-cpython-311/custom_rasterizer/render.py -> build/bdist.linux-x86_64/egg/custom_rasterizer
# copying build/lib.linux-x86_64-cpython-311/custom_rasterizer/io_obj.py -> build/bdist.linux-x86_64/egg/custom_rasterizer
# byte-compiling build/bdist.linux-x86_64/egg/custom_rasterizer/io_glb.py to io_glb.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/custom_rasterizer/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/custom_rasterizer/render.py to render.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/custom_rasterizer/io_obj.py to io_obj.cpython-311.pyc
# creating stub loader for custom_rasterizer_kernel.cpython-311-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/custom_rasterizer_kernel.py to custom_rasterizer_kernel.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying custom_rasterizer.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying custom_rasterizer.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying custom_rasterizer.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying custom_rasterizer.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.custom_rasterizer_kernel.cpython-311: module references __file__
# creating dist
# creating 'dist/custom_rasterizer-0.1-py3.11-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing custom_rasterizer-0.1-py3.11-linux-x86_64.egg
# creating /usr/local/lib/python3.11/dist-packages/custom_rasterizer-0.1-py3.11-linux-x86_64.egg
# Extracting custom_rasterizer-0.1-py3.11-linux-x86_64.egg to /usr/local/lib/python3.11/dist-packages
# Adding custom-rasterizer 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.11/dist-packages/custom_rasterizer-0.1-py3.11-linux-x86_64.egg
# Processing dependencies for custom-rasterizer==0.1
# Finished processing dependencies for custom-rasterizer==0.1
# /content/Hunyuan3D-2
# /content/Hunyuan3D-2/hy3dgen/texgen/differentiable_renderer
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating mesh_processor.egg-info
# writing mesh_processor.egg-info/PKG-INFO
# writing dependency_links to mesh_processor.egg-info/dependency_links.txt
# writing requirements to mesh_processor.egg-info/requires.txt
# writing top-level names to mesh_processor.egg-info/top_level.txt
# writing manifest file 'mesh_processor.egg-info/SOURCES.txt'
# reading manifest file 'mesh_processor.egg-info/SOURCES.txt'
# writing manifest file 'mesh_processor.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'mesh_processor' extension
# creating build/temp.linux-x86_64-cpython-311
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/pybind11/include -I/usr/local/lib/python3.11/dist-packages/pybind11/include -I/usr/include/python3.11 -c mesh_processor.cpp -o build/temp.linux-x86_64-cpython-311/mesh_processor.o -O3 -std=c++14 -fPIC -Wall -Wextra -pthread
# creating build/lib.linux-x86_64-cpython-311
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions build/temp.linux-x86_64-cpython-311/mesh_processor.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/mesh_processor.cpython-311-x86_64-linux-gnu.so -fPIC -pthread
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-311/mesh_processor.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for mesh_processor.cpython-311-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/mesh_processor.py to mesh_processor.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mesh_processor.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mesh_processor.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mesh_processor.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mesh_processor.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mesh_processor.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.mesh_processor.cpython-311: module references __file__
# creating dist
# creating 'dist/mesh_processor-0.0.0-py3.11-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mesh_processor-0.0.0-py3.11-linux-x86_64.egg
# creating /usr/local/lib/python3.11/dist-packages/mesh_processor-0.0.0-py3.11-linux-x86_64.egg
# Extracting mesh_processor-0.0.0-py3.11-linux-x86_64.egg to /usr/local/lib/python3.11/dist-packages
# Adding mesh-processor 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.11/dist-packages/mesh_processor-0.0.0-py3.11-linux-x86_64.egg
# Processing dependencies for mesh-processor==0.0.0
# Searching for pybind11==2.13.6
# Best match: pybind11 2.13.6
# Adding pybind11 2.13.6 to easy-install.pth file
# detected new path './mesh_processor-0.0.0-py3.11-linux-x86_64.egg'
# Installing pybind11-config script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Finished processing dependencies for mesh-processor==0.0.0
# /content/Hunyuan3D-2

# %%
# Out:
# /content/Hunyuan3D-2

# %% [markdown]
# ## 2) Mesh Generation

# %%
from hy3dgen.texgen import Hunyuan3DPaintPipeline
from hy3dgen.shapegen import Hunyuan3DDiTFlowMatchingPipeline

# let's generate a mesh first
pipeline = Hunyuan3DDiTFlowMatchingPipeline.from_pretrained('tencent/Hunyuan3D-2', device='cuda')
mesh = pipeline(image='assets/demo.png')[0]
# pipeline = Hunyuan3DPaintPipeline.from_pretrained('tencent/Hunyuan3D-2')
# mesh = pipeline(mesh, image='assets/demo.png')

# %%
mesh.show()

# %%
# mesh.export('output_mesh.obj')
import trimesh
mesh = trimesh.load('output_mesh.obj')

# %%
## Cleaining up RAM/VRAM

import torch
import gc
del pipeline
torch.cuda.empty_cache()
gc.collect()
# Out:
# 51

# %% [markdown]
# ## 3) Texture Generation

# %%
import trimesh

# %%
pipeline = Hunyuan3DPaintPipeline.from_pretrained('tencent/Hunyuan3D-2')
# mesh = pipeline(mesh, image='assets/demo.png')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# scheduler_config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# model_index.json:   0%|          | 0.00/621 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/681M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/787 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/672 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# model_index.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/7.33G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.72G [00:00<?, ?B/s]
# modules.py: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--tencent--Hunyuan3D-2/snapshots/34e28261f71c32975727be8db0eace439a280f82/hunyuan3d-paint-v2-0-turbo/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--tencent--Hunyuan3D-2/snapshots/34e28261f71c32975727be8db0eace439a280f82/hunyuan3d-paint-v2-0-turbo/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
