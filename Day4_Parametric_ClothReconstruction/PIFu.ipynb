# %% [markdown]
# # PIFu: Pixel-Aligned Implicit Function for High-Resolution Clothed Human Digitization
# This notebook contains the demo code for training and inference of [PIFu](https://arxiv.org/pdf/1905.05172.pdf) code.
#
#
# ## Note
# Before running this notebook make sure that your runtime type is 'Python 3 with GPU acceleration'. Go to Edit > Notebook settings > Hardware Accelerator > Select "GPU".
#
# ## More Info
# - Paper: https://arxiv.org/pdf/1905.05172.pdf
# - Repo: https://github.com/shunsukesaito/PIFu
# - Project Page: https://shunsukesaito.github.io/PIFu/

# %%
# !pip install pyexr
# !pip install trimesh
# !pip install rtree
# Out:
# Collecting pyexr
#   Downloading pyexr-0.5.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting OpenEXR>=3.2.3 (from pyexr)
#   Downloading openexr-3.3.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from pyexr) (2.0.2)
# Downloading pyexr-0.5.0-py3-none-any.whl (6.9 kB)
# Downloading openexr-3.3.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# Installing collected packages: OpenEXR, pyexr
# Successfully installed OpenEXR-3.3.4 pyexr-0.5.0
# Collecting trimesh
#   Downloading trimesh-4.6.12-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from trimesh) (2.0.2)
# Downloading trimesh-4.6.12-py3-none-any.whl (711 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 712.0/712.0 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: trimesh
# Successfully installed trimesh-4.6.12
# Collecting rtree
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: rtree
# Successfully installed rtree-1.4.0

# %%
import os

# %%
os.environ["OPENCV_IO_ENABLE_OPENEXR"]="1"

# %% [markdown]
# ## Getting started

# %%
# !gdown --id 1pIB0fD9CLtrG0hIrhtM5O7kJS63EeU7B
# !unzip PIFu.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1pIB0fD9CLtrG0hIrhtM5O7kJS63EeU7B
# To: /content/PIFu.zip
# 100% 168k/168k [00:00<00:00, 40.2MB/s]
# Archive:  PIFu.zip
#    creating: PIFu/apps/
#  extracting: PIFu/apps/__init__.py
#   inflating: PIFu/apps/crop_img.py
#   inflating: PIFu/apps/eval.py
#   inflating: PIFu/apps/prt_util.py
#   inflating: PIFu/apps/render_data.py
#   inflating: PIFu/apps/train_color.py
#   inflating: PIFu/apps/train_shape.py
#   inflating: PIFu/env_sh.npy
#   inflating: PIFu/environment.yml
#    creating: PIFu/lib/
#  extracting: PIFu/lib/__init__.py
#    creating: PIFu/lib/__pycache__/
#   inflating: PIFu/lib/__pycache__/__init__.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/geometry.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/mesh_util.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/net_util.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/options.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/sample_util.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/sdf.cpython-38.pyc
#   inflating: PIFu/lib/__pycache__/train_util.cpython-38.pyc
#   inflating: PIFu/lib/colab_util.py
#    creating: PIFu/lib/data/
#   inflating: PIFu/lib/data/__init__.py
#    creating: PIFu/lib/data/__pycache__/
#   inflating: PIFu/lib/data/__pycache__/__init__.cpython-38.pyc
#   inflating: PIFu/lib/data/__pycache__/EvalDataset.cpython-38.pyc
#   inflating: PIFu/lib/data/__pycache__/TrainDataset.cpython-38.pyc
#   inflating: PIFu/lib/data/BaseDataset.py
#   inflating: PIFu/lib/data/EvalDataset.py
#   inflating: PIFu/lib/data/TrainDataset.py
#   inflating: PIFu/lib/ext_transform.py
#   inflating: PIFu/lib/geometry.py
#   inflating: PIFu/lib/mesh_util.py
#    creating: PIFu/lib/model/
#   inflating: PIFu/lib/model/__init__.py
#    creating: PIFu/lib/model/__pycache__/
#   inflating: PIFu/lib/model/__pycache__/__init__.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/BasePIFuNet.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/ConvFilters.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/ConvPIFuNet.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/DepthNormalizer.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/HGFilters.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/HGPIFuNet.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/ResBlkPIFuNet.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/SurfaceClassifier.cpython-38.pyc
#   inflating: PIFu/lib/model/__pycache__/VhullPIFuNet.cpython-38.pyc
#   inflating: PIFu/lib/model/BasePIFuNet.py
#   inflating: PIFu/lib/model/ConvFilters.py
#   inflating: PIFu/lib/model/ConvPIFuNet.py
#   inflating: PIFu/lib/model/DepthNormalizer.py
#   inflating: PIFu/lib/model/HGFilters.py
#   inflating: PIFu/lib/model/HGPIFuNet.py
#   inflating: PIFu/lib/model/ResBlkPIFuNet.py
#   inflating: PIFu/lib/model/SurfaceClassifier.py
#   inflating: PIFu/lib/model/VhullPIFuNet.py
#   inflating: PIFu/lib/net_util.py
#   inflating: PIFu/lib/options.py
#    creating: PIFu/lib/renderer/
#  extracting: PIFu/lib/renderer/__init__.py
#   inflating: PIFu/lib/renderer/camera.py
#    creating: PIFu/lib/renderer/gl/
#  extracting: PIFu/lib/renderer/gl/__init__.py
#   inflating: PIFu/lib/renderer/gl/cam_render.py
#    creating: PIFu/lib/renderer/gl/data/
#   inflating: PIFu/lib/renderer/gl/data/prt.fs
#   inflating: PIFu/lib/renderer/gl/data/prt.vs
#   inflating: PIFu/lib/renderer/gl/data/prt_uv.fs
#   inflating: PIFu/lib/renderer/gl/data/prt_uv.vs
#   inflating: PIFu/lib/renderer/gl/data/quad.fs
#   inflating: PIFu/lib/renderer/gl/data/quad.vs
#   inflating: PIFu/lib/renderer/gl/framework.py
#   inflating: PIFu/lib/renderer/gl/glcontext.py
#   inflating: PIFu/lib/renderer/gl/init_gl.py
#   inflating: PIFu/lib/renderer/gl/prt_render.py
#   inflating: PIFu/lib/renderer/gl/render.py
#   inflating: PIFu/lib/renderer/glm.py
#   inflating: PIFu/lib/renderer/mesh.py
#   inflating: PIFu/lib/sample_util.py
#   inflating: PIFu/lib/sdf.py
#   inflating: PIFu/lib/train_util.py
#   inflating: PIFu/LICENSE.txt
#   inflating: PIFu/README.md
#   inflating: PIFu/requirements.txt
#    creating: PIFu/scripts/
#   inflating: PIFu/scripts/download_trained_model.sh
#   inflating: PIFu/scripts/test.sh

# %%
# %cd /content/PIFu
# Out:
# /content/PIFu

# %%
# !sh ./scripts/download_trained_model.sh
# Out:
# + mkdir -p checkpoints
# + cd checkpoints
# + wget https://drive.google.com/uc?export=download&id=1zEmVXG2VHy0MMzngcRshB4D8Sr_oLHsm -O net_G
# --2025-06-25 12:24:17--  https://drive.google.com/uc?export=download&id=1zEmVXG2VHy0MMzngcRshB4D8Sr_oLHsm
# Resolving drive.google.com (drive.google.com)... 173.194.174.101, 173.194.174.113, 173.194.174.102, ...
# Connecting to drive.google.com (drive.google.com)|173.194.174.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1zEmVXG2VHy0MMzngcRshB4D8Sr_oLHsm&export=download [following]
# --2025-06-25 12:24:17--  https://drive.usercontent.google.com/download?id=1zEmVXG2VHy0MMzngcRshB4D8Sr_oLHsm&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.23.132, 2404:6800:4008:c02::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.23.132|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-06-25 12:24:17 ERROR 404: Not Found.

# %% [markdown]
# ## Data generation (Not Supported by Colab)
#
# For training for custom data, it needs to be preprocessed. Each ".obj" file needs to be processed by following two commands.

# %%
# !python -m apps.prt_util -i {path_to_OBJ}
# !python -m apps.render_data -i {path_to_OBJ} -o {path_to_training_data} [-e]

# %% [markdown]
# ## Download pre-processed data

# %%
# !gdown --id 1eizCurA2_xtIUUJXu_G20kyQWxHBkjGE
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1eizCurA2_xtIUUJXu_G20kyQWxHBkjGE
# From (redirected): https://drive.google.com/uc?id=1eizCurA2_xtIUUJXu_G20kyQWxHBkjGE&confirm=t&uuid=efb1341c-b7ed-4537-aa46-1cb596de3ca8
# To: /content/PIFu/demo_train.zip
# 100% 34.4M/34.4M [00:00<00:00, 46.5MB/s]

# %%
# !unzip demo_train
# Out:
# Archive:  demo_train.zip
#    creating: demo_train1/
#    creating: demo_train1/GEO/
#    creating: demo_train1/GEO/OBJ/
#    creating: demo_train1/GEO/OBJ/1/
#   inflating: demo_train1/GEO/OBJ/1/1_100k.obj
#    creating: demo_train1/MASK/
#    creating: demo_train1/MASK/1/
#   inflating: demo_train1/MASK/1/0_0_00.png
#   inflating: demo_train1/MASK/1/100_0_00.png
#   inflating: demo_train1/MASK/1/101_0_00.png
#   inflating: demo_train1/MASK/1/102_0_00.png
#   inflating: demo_train1/MASK/1/103_0_00.png
#   inflating: demo_train1/MASK/1/104_0_00.png
#   inflating: demo_train1/MASK/1/105_0_00.png
#   inflating: demo_train1/PARAM/1/84_0_00.npy
#   inflating: demo_train1/PARAM/1/85_0_00.npy
#   inflating: demo_train1/PARAM/1/86_0_00.npy
#   inflating: demo_train1/PARAM/1/87_0_00.npy
#   inflating: demo_train1/PARAM/1/88_0_00.npy
#   inflating: demo_train1/PARAM/1/89_0_00.npy
#   inflating: demo_train1/PARAM/1/8_0_00.npy
#   inflating: demo_train1/PARAM/1/90_0_00.npy
#   inflating: demo_train1/PARAM/1/91_0_00.npy
#   inflating: demo_train1/PARAM/1/92_0_00.npy
#   inflating: demo_train1/PARAM/1/93_0_00.npy
#   inflating: demo_train1/PARAM/1/94_0_00.npy
#   inflating: demo_train1/PARAM/1/95_0_00.npy
#   inflating: demo_train1/PARAM/1/96_0_00.npy
#   inflating: demo_train1/PARAM/1/97_0_00.npy
#   inflating: demo_train1/PARAM/1/98_0_00.npy
#   inflating: demo_train1/PARAM/1/99_0_00.npy
#   inflating: demo_train1/PARAM/1/9_0_00.npy
#    creating: demo_train1/RENDER/
#    creating: demo_train1/RENDER/1/
#   inflating: demo_train1/RENDER/1/0_0_00.jpg
#   inflating: demo_train1/RENDER/1/100_0_00.jpg
#   inflating: demo_train1/RENDER/1/101_0_00.jpg
#   inflating: demo_train1/RENDER/1/102_0_00.jpg
#   inflating: demo_train1/RENDER/1/103_0_00.jpg
#   inflating: demo_train1/RENDER/1/104_0_00.jpg
#   inflating: demo_train1/RENDER/1/105_0_00.jpg
#   inflating: demo_train1/RENDER/1/106_0_00.jpg
#   inflating: demo_train1/RENDER/1/107_0_00.jpg
#   inflating: demo_train1/RENDER/1/108_0_00.jpg
#   inflating: demo_train1/RENDER/1/109_0_00.jpg
#   inflating: demo_train1/RENDER/1/10_0_00.jpg
#   inflating: demo_train1/RENDER/1/110_0_00.jpg
#   inflating: demo_train1/RENDER/1/111_0_00.jpg
#   inflating: demo_train1/RENDER/1/112_0_00.jpg
#   inflating: demo_train1/RENDER/1/113_0_00.jpg
#   inflating: demo_train1/RENDER/1/114_0_00.jpg
#   inflating: demo_train1/RENDER/1/115_0_00.jpg
#   inflating: demo_train1/RENDER/1/116_0_00.jpg
#   inflating: demo_train1/RENDER/1/117_0_00.jpg
#   inflating: demo_train1/RENDER/1/118_0_00.jpg
#   inflating: demo_train1/RENDER/1/119_0_00.jpg
#   inflating: demo_train1/RENDER/1/11_0_00.jpg
#   inflating: demo_train1/RENDER/1/120_0_00.jpg
#   inflating: demo_train1/RENDER/1/121_0_00.jpg
#   inflating: demo_train1/RENDER/1/122_0_00.jpg
#   inflating: demo_train1/RENDER/1/123_0_00.jpg
#   inflating: demo_train1/RENDER/1/124_0_00.jpg
#   inflating: demo_train1/RENDER/1/125_0_00.jpg
#   inflating: demo_train1/RENDER/1/126_0_00.jpg
#   inflating: demo_train1/RENDER/1/127_0_00.jpg
#   inflating: demo_train1/RENDER/1/128_0_00.jpg
#   inflating: demo_train1/RENDER/1/129_0_00.jpg
#   inflating: demo_train1/RENDER/1/12_0_00.jpg
#   inflating: demo_train1/RENDER/1/130_0_00.jpg
#   inflating: demo_train1/RENDER/1/131_0_00.jpg
#   inflating: demo_train1/RENDER/1/132_0_00.jpg
#   inflating: demo_train1/RENDER/1/133_0_00.jpg
#   inflating: demo_train1/RENDER/1/134_0_00.jpg
#   inflating: demo_train1/RENDER/1/135_0_00.jpg
#   inflating: demo_train1/RENDER/1/136_0_00.jpg
#   inflating: demo_train1/RENDER/1/137_0_00.jpg
#   inflating: demo_train1/RENDER/1/138_0_00.jpg
#   inflating: demo_train1/RENDER/1/139_0_00.jpg
#   inflating: demo_train1/RENDER/1/13_0_00.jpg
#   inflating: demo_train1/RENDER/1/140_0_00.jpg
#   inflating: demo_train1/RENDER/1/141_0_00.jpg
#   inflating: demo_train1/RENDER/1/142_0_00.jpg
#   inflating: demo_train1/RENDER/1/143_0_00.jpg
#   inflating: demo_train1/RENDER/1/144_0_00.jpg
#   inflating: demo_train1/RENDER/1/145_0_00.jpg
#   inflating: demo_train1/RENDER/1/146_0_00.jpg
#   inflating: demo_train1/RENDER/1/147_0_00.jpg
#   inflating: demo_train1/RENDER/1/148_0_00.jpg
#   inflating: demo_train1/RENDER/1/149_0_00.jpg
#   inflating: demo_train1/RENDER/1/14_0_00.jpg
#   inflating: demo_train1/RENDER/1/150_0_00.jpg
#   inflating: demo_train1/RENDER/1/151_0_00.jpg
#   inflating: demo_train1/RENDER/1/152_0_00.jpg
#   inflating: demo_train1/RENDER/1/153_0_00.jpg
#   inflating: demo_train1/RENDER/1/154_0_00.jpg
#   inflating: demo_train1/RENDER/1/155_0_00.jpg
#   inflating: demo_train1/RENDER/1/156_0_00.jpg
#   inflating: demo_train1/RENDER/1/157_0_00.jpg
#   inflating: demo_train1/RENDER/1/158_0_00.jpg
#   inflating: demo_train1/RENDER/1/159_0_00.jpg
#   inflating: demo_train1/RENDER/1/15_0_00.jpg
#   inflating: demo_train1/RENDER/1/160_0_00.jpg
#   inflating: demo_train1/RENDER/1/161_0_00.jpg
#   inflating: demo_train1/RENDER/1/162_0_00.jpg
#   inflating: demo_train1/RENDER/1/163_0_00.jpg
#   inflating: demo_train1/RENDER/1/164_0_00.jpg
#   inflating: demo_train1/RENDER/1/165_0_00.jpg
#   inflating: demo_train1/RENDER/1/166_0_00.jpg
#   inflating: demo_train1/RENDER/1/167_0_00.jpg
#   inflating: demo_train1/RENDER/1/168_0_00.jpg
#   inflating: demo_train1/RENDER/1/169_0_00.jpg
#   inflating: demo_train1/RENDER/1/16_0_00.jpg
#   inflating: demo_train1/RENDER/1/170_0_00.jpg
#   inflating: demo_train1/RENDER/1/171_0_00.jpg
#   inflating: demo_train1/RENDER/1/172_0_00.jpg
#   inflating: demo_train1/RENDER/1/173_0_00.jpg
#   inflating: demo_train1/RENDER/1/174_0_00.jpg
#   inflating: demo_train1/RENDER/1/175_0_00.jpg
#   inflating: demo_train1/RENDER/1/176_0_00.jpg
#   inflating: demo_train1/RENDER/1/177_0_00.jpg
#   inflating: demo_train1/RENDER/1/178_0_00.jpg
#   inflating: demo_train1/RENDER/1/179_0_00.jpg
#   inflating: demo_train1/RENDER/1/17_0_00.jpg
#   inflating: demo_train1/RENDER/1/180_0_00.jpg
#   inflating: demo_train1/RENDER/1/181_0_00.jpg
#   inflating: demo_train1/RENDER/1/182_0_00.jpg
#   inflating: demo_train1/RENDER/1/183_0_00.jpg
#   inflating: demo_train1/RENDER/1/184_0_00.jpg
#   inflating: demo_train1/RENDER/1/185_0_00.jpg
#   inflating: demo_train1/RENDER/1/186_0_00.jpg
#   inflating: demo_train1/RENDER/1/187_0_00.jpg
#   inflating: demo_train1/RENDER/1/188_0_00.jpg
#   inflating: demo_train1/RENDER/1/189_0_00.jpg
#   inflating: demo_train1/RENDER/1/18_0_00.jpg
#   inflating: demo_train1/RENDER/1/190_0_00.jpg
#   inflating: demo_train1/RENDER/1/191_0_00.jpg
#   inflating: demo_train1/RENDER/1/192_0_00.jpg
#   inflating: demo_train1/RENDER/1/193_0_00.jpg
#   inflating: demo_train1/RENDER/1/194_0_00.jpg
#   inflating: demo_train1/RENDER/1/195_0_00.jpg
#   inflating: demo_train1/RENDER/1/196_0_00.jpg
#   inflating: demo_train1/RENDER/1/197_0_00.jpg
#   inflating: demo_train1/RENDER/1/198_0_00.jpg
#   inflating: demo_train1/RENDER/1/199_0_00.jpg
#   inflating: demo_train1/RENDER/1/19_0_00.jpg
#   inflating: demo_train1/RENDER/1/1_0_00.jpg
#   inflating: demo_train1/RENDER/1/200_0_00.jpg
#   inflating: demo_train1/RENDER/1/201_0_00.jpg
#   inflating: demo_train1/RENDER/1/202_0_00.jpg
#   inflating: demo_train1/RENDER/1/203_0_00.jpg
#   inflating: demo_train1/RENDER/1/204_0_00.jpg
#   inflating: demo_train1/RENDER/1/205_0_00.jpg
#   inflating: demo_train1/RENDER/1/206_0_00.jpg
#   inflating: demo_train1/RENDER/1/207_0_00.jpg
#   inflating: demo_train1/RENDER/1/208_0_00.jpg
#   inflating: demo_train1/RENDER/1/209_0_00.jpg
#   inflating: demo_train1/RENDER/1/20_0_00.jpg
#   inflating: demo_train1/RENDER/1/210_0_00.jpg
#   inflating: demo_train1/RENDER/1/211_0_00.jpg
#   inflating: demo_train1/RENDER/1/212_0_00.jpg
#   inflating: demo_train1/RENDER/1/213_0_00.jpg
#   inflating: demo_train1/RENDER/1/214_0_00.jpg
#   inflating: demo_train1/RENDER/1/215_0_00.jpg
#   inflating: demo_train1/RENDER/1/216_0_00.jpg
#   inflating: demo_train1/RENDER/1/217_0_00.jpg
#   inflating: demo_train1/RENDER/1/218_0_00.jpg
#   inflating: demo_train1/RENDER/1/219_0_00.jpg
#   inflating: demo_train1/RENDER/1/21_0_00.jpg
#   inflating: demo_train1/RENDER/1/220_0_00.jpg
#   inflating: demo_train1/RENDER/1/221_0_00.jpg
#   inflating: demo_train1/RENDER/1/222_0_00.jpg
#   inflating: demo_train1/RENDER/1/223_0_00.jpg
#   inflating: demo_train1/RENDER/1/224_0_00.jpg
#   inflating: demo_train1/RENDER/1/225_0_00.jpg
#   inflating: demo_train1/RENDER/1/226_0_00.jpg
#   inflating: demo_train1/RENDER/1/227_0_00.jpg
#   inflating: demo_train1/RENDER/1/228_0_00.jpg
#   inflating: demo_train1/RENDER/1/229_0_00.jpg
#   inflating: demo_train1/RENDER/1/22_0_00.jpg
#   inflating: demo_train1/RENDER/1/230_0_00.jpg
#   inflating: demo_train1/RENDER/1/231_0_00.jpg
#   inflating: demo_train1/RENDER/1/232_0_00.jpg
#   inflating: demo_train1/RENDER/1/233_0_00.jpg
#   inflating: demo_train1/RENDER/1/234_0_00.jpg
#   inflating: demo_train1/RENDER/1/235_0_00.jpg
#   inflating: demo_train1/RENDER/1/236_0_00.jpg
#   inflating: demo_train1/RENDER/1/237_0_00.jpg
#   inflating: demo_train1/RENDER/1/238_0_00.jpg
#   inflating: demo_train1/RENDER/1/239_0_00.jpg
#   inflating: demo_train1/RENDER/1/23_0_00.jpg
#   inflating: demo_train1/RENDER/1/240_0_00.jpg
#   inflating: demo_train1/RENDER/1/241_0_00.jpg
#   inflating: demo_train1/RENDER/1/242_0_00.jpg
#   inflating: demo_train1/RENDER/1/243_0_00.jpg
#   inflating: demo_train1/RENDER/1/244_0_00.jpg
#   inflating: demo_train1/RENDER/1/245_0_00.jpg
#   inflating: demo_train1/RENDER/1/246_0_00.jpg
#   inflating: demo_train1/RENDER/1/247_0_00.jpg
#   inflating: demo_train1/RENDER/1/248_0_00.jpg
#   inflating: demo_train1/RENDER/1/249_0_00.jpg
#   inflating: demo_train1/RENDER/1/24_0_00.jpg
#   inflating: demo_train1/RENDER/1/250_0_00.jpg
#   inflating: demo_train1/RENDER/1/251_0_00.jpg
#   inflating: demo_train1/RENDER/1/252_0_00.jpg
#   inflating: demo_train1/RENDER/1/253_0_00.jpg
#   inflating: demo_train1/RENDER/1/254_0_00.jpg
#   inflating: demo_train1/RENDER/1/255_0_00.jpg
#   inflating: demo_train1/RENDER/1/256_0_00.jpg
#   inflating: demo_train1/RENDER/1/257_0_00.jpg
#   inflating: demo_train1/RENDER/1/258_0_00.jpg
#   inflating: demo_train1/RENDER/1/259_0_00.jpg
#   inflating: demo_train1/RENDER/1/25_0_00.jpg
#   inflating: demo_train1/RENDER/1/260_0_00.jpg
#   inflating: demo_train1/RENDER/1/261_0_00.jpg
#   inflating: demo_train1/RENDER/1/262_0_00.jpg
#   inflating: demo_train1/RENDER/1/263_0_00.jpg
#   inflating: demo_train1/RENDER/1/264_0_00.jpg
#   inflating: demo_train1/RENDER/1/265_0_00.jpg
#   inflating: demo_train1/RENDER/1/266_0_00.jpg
#   inflating: demo_train1/RENDER/1/267_0_00.jpg
#   inflating: demo_train1/RENDER/1/268_0_00.jpg
#   inflating: demo_train1/RENDER/1/269_0_00.jpg
#   inflating: demo_train1/RENDER/1/26_0_00.jpg
#   inflating: demo_train1/RENDER/1/270_0_00.jpg
#   inflating: demo_train1/RENDER/1/271_0_00.jpg
#   inflating: demo_train1/RENDER/1/272_0_00.jpg
#   inflating: demo_train1/RENDER/1/273_0_00.jpg
#   inflating: demo_train1/RENDER/1/274_0_00.jpg
#   inflating: demo_train1/RENDER/1/275_0_00.jpg
#   inflating: demo_train1/RENDER/1/276_0_00.jpg
#   inflating: demo_train1/RENDER/1/277_0_00.jpg
#   inflating: demo_train1/RENDER/1/278_0_00.jpg
#   inflating: demo_train1/RENDER/1/279_0_00.jpg
#   inflating: demo_train1/RENDER/1/27_0_00.jpg
#   inflating: demo_train1/RENDER/1/280_0_00.jpg
#   inflating: demo_train1/RENDER/1/281_0_00.jpg
#   inflating: demo_train1/RENDER/1/282_0_00.jpg
#   inflating: demo_train1/RENDER/1/283_0_00.jpg
#   inflating: demo_train1/RENDER/1/284_0_00.jpg
#   inflating: demo_train1/RENDER/1/285_0_00.jpg
#   inflating: demo_train1/RENDER/1/286_0_00.jpg
#   inflating: demo_train1/RENDER/1/287_0_00.jpg
#   inflating: demo_train1/RENDER/1/288_0_00.jpg
#   inflating: demo_train1/RENDER/1/289_0_00.jpg
#   inflating: demo_train1/RENDER/1/28_0_00.jpg
#   inflating: demo_train1/RENDER/1/290_0_00.jpg
#   inflating: demo_train1/RENDER/1/291_0_00.jpg
#   inflating: demo_train1/RENDER/1/292_0_00.jpg
#   inflating: demo_train1/RENDER/1/293_0_00.jpg
#   inflating: demo_train1/RENDER/1/294_0_00.jpg
#   inflating: demo_train1/RENDER/1/295_0_00.jpg
#   inflating: demo_train1/RENDER/1/296_0_00.jpg
#   inflating: demo_train1/RENDER/1/297_0_00.jpg
#   inflating: demo_train1/RENDER/1/298_0_00.jpg
#   inflating: demo_train1/RENDER/1/299_0_00.jpg
#   inflating: demo_train1/RENDER/1/29_0_00.jpg
#   inflating: demo_train1/RENDER/1/2_0_00.jpg
#   inflating: demo_train1/RENDER/1/300_0_00.jpg
#   inflating: demo_train1/RENDER/1/301_0_00.jpg
#   inflating: demo_train1/RENDER/1/302_0_00.jpg
#   inflating: demo_train1/RENDER/1/303_0_00.jpg
#   inflating: demo_train1/RENDER/1/304_0_00.jpg
#   inflating: demo_train1/RENDER/1/305_0_00.jpg
#   inflating: demo_train1/RENDER/1/306_0_00.jpg
#   inflating: demo_train1/RENDER/1/307_0_00.jpg
#   inflating: demo_train1/RENDER/1/308_0_00.jpg
#   inflating: demo_train1/RENDER/1/309_0_00.jpg
#   inflating: demo_train1/RENDER/1/30_0_00.jpg
#   inflating: demo_train1/RENDER/1/310_0_00.jpg
#   inflating: demo_train1/RENDER/1/311_0_00.jpg
#   inflating: demo_train1/RENDER/1/312_0_00.jpg
#   inflating: demo_train1/RENDER/1/313_0_00.jpg
#   inflating: demo_train1/RENDER/1/314_0_00.jpg
#   inflating: demo_train1/RENDER/1/315_0_00.jpg
#   inflating: demo_train1/RENDER/1/316_0_00.jpg
#   inflating: demo_train1/RENDER/1/317_0_00.jpg
#   inflating: demo_train1/RENDER/1/318_0_00.jpg
#   inflating: demo_train1/RENDER/1/319_0_00.jpg
#   inflating: demo_train1/RENDER/1/31_0_00.jpg
#   inflating: demo_train1/RENDER/1/320_0_00.jpg
#   inflating: demo_train1/RENDER/1/321_0_00.jpg
#   inflating: demo_train1/RENDER/1/322_0_00.jpg
#   inflating: demo_train1/RENDER/1/323_0_00.jpg
#   inflating: demo_train1/RENDER/1/324_0_00.jpg
#   inflating: demo_train1/RENDER/1/325_0_00.jpg
0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/315_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/316_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/317_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/318_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/319_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/31_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/320_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/321_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/322_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/323_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/324_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/325_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/326_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/327_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/328_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/329_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/32_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/330_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/331_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/332_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/333_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/334_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/335_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/336_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/337_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/338_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/339_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/33_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/340_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/341_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/342_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/343_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/344_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/345_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/346_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/347_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/348_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/349_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/34_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/350_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/351_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/352_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/353_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/354_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/355_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/356_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/357_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/358_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/359_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/35_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/36_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/37_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/38_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/39_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/3_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/40_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/41_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/42_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/43_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/44_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/45_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/46_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/47_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/48_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/49_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/4_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/50_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/51_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/52_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/53_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/54_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/55_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/56_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/57_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/58_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/59_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/5_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/60_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/61_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/62_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/63_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/64_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/65_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/66_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/67_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/68_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/69_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/6_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/70_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/71_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/72_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/73_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/74_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/75_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/76_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/77_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/78_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/79_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/7_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/80_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/81_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/82_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/83_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/84_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/85_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/86_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/87_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/88_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/89_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/8_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/90_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/91_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/92_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/93_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/94_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/95_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/96_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/97_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/98_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/99_0_00.jpg
#   inflating: demo_train1/UV_RENDER/1/9_0_00.jpg
#  extracting: demo_train1/val.txt

# %%
# import libraries
import sys
import os
import time
import json
import numpy as np
import cv2
import random
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
import argparse

from lib.options import BaseOptions
from lib.mesh_util import *
from lib.sample_util import *
from lib.train_util import *
from lib.data import *
from lib.model import *
from lib.geometry import index

# %%
#parse arguments
opt = BaseOptions()
parser = argparse.ArgumentParser(
                formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser = opt.initialize(parser)
opt = parser.parse_args([])

# %%
#set parameters
opt.num_epoch = 1
opt.dataroot = 'demo_train1'
opt.num_sample_inout = 500

# set cuda
cuda = torch.device('cuda:%d' % opt.gpu_id)

# %%
#load data
from lib.data.TrainDataset import TrainDataset
train_dataset = TrainDataset(opt, phase='train')
test_dataset = TrainDataset(opt, phase='test')

# create data loader
train_data_loader = DataLoader(train_dataset,
                                batch_size=opt.batch_size, shuffle=not opt.serial_batches,
                                num_workers=opt.num_threads, pin_memory=opt.pin_memory)

print('train data size: ', len(train_data_loader))

# NOTE: batch size should be 1 and use all the points for evaluation
test_data_loader = DataLoader(test_dataset,
                                batch_size=1, shuffle=False,
                                num_workers=opt.num_threads, pin_memory=opt.pin_memory)
print('test data size: ', len(test_data_loader))
# Out:
# /content/PIFu/lib/data/TrainDataset.py:102: UserWarning: loadtxt: input contained no data: "demo_train1/val.txt"
#   var_subjects = np.loadtxt(os.path.join(self.root, 'val.txt'), dtype=str)
# /content/PIFu/lib/data/TrainDataset.py:102: UserWarning: loadtxt: input contained no data: "demo_train1/val.txt"
#   var_subjects = np.loadtxt(os.path.join(self.root, 'val.txt'), dtype=str)
# train data size:  180
# test data size:  360

# %%
# create net
projection_mode = train_dataset.projection_mode

netG = HGPIFuNet(opt, projection_mode).to(device=cuda)
optimizerG = torch.optim.RMSprop(netG.parameters(), lr=opt.learning_rate, momentum=0, weight_decay=0)
lr = opt.learning_rate
print('Using Network: ', netG.name)
# Out:
# initialize network with normal
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-15-420061197.py in <cell line: 0>()
#       2 projection_mode = train_dataset.projection_mode
#       3
# ----> 4 netG = HGPIFuNet(opt, projection_mode).to(device=cuda)
#       5 optimizerG = torch.optim.RMSprop(netG.parameters(), lr=opt.learning_rate, momentum=0, weight_decay=0)
#       6 lr = opt.learning_rate
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1341                     raise
#    1342
# -> 1343         return self._apply(convert)
#    1344
#    1345     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     901         if recurse:
#     902             for module in self.children():
# --> 903                 module._apply(fn)
#     904
#     905         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     928             # `with torch.no_grad():`
#     929             with torch.no_grad():
# --> 930                 param_applied = fn(param)
#     931             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     932
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in convert(t)
#    1327                         memory_format=convert_to_format,
#    1328                     )
# -> 1329                 return t.to(
#    1330                     device,
#    1331                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# /usr/local/lib/python3.11/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     317         if "CUDA_MODULE_LOADING" not in os.environ:
#     318             os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 319         torch._C._cuda_init()
#     320         # Some of the queued calls may reentrantly call _lazy_init();
#     321         # we need to just return without initializing in that case.
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
#set mode
def set_train():
    netG.train()

def set_eval():
    netG.eval()

# %%
# # load checkpoints
# checkpoint_path = "/content/PIFu/checkpoints/net_G"
# print('loading for net G ...', checkpoint_path)
# netG.load_state_dict(torch.load(checkpoint_path, map_location=cuda))

# %%
# train
for epoch in range(opt.num_epoch):
    epoch_start_time = time.time()

    set_train()
    iter_data_time = time.time()

    for train_idx, train_data in enumerate(train_data_loader):
        iter_start_time = time.time()

        # retrieve the data
        image_tensor = train_data['img'].to(device=cuda)
        calib_tensor = train_data['calib'].to(device=cuda)
        sample_tensor = train_data['samples'].to(device=cuda)


        image_tensor, calib_tensor = reshape_multiview_tensors(image_tensor, calib_tensor)
        label_tensor = train_data['labels'].to(device=cuda)

        res, error = netG.forward(image_tensor, sample_tensor, calib_tensor,  labels=label_tensor)

        optimizerG.zero_grad()
        error.backward()
        optimizerG.step()

        iter_net_time = time.time()
        eta = ((iter_net_time - epoch_start_time) / (train_idx + 1)) * len(train_data_loader) - (
                iter_net_time - epoch_start_time)

        if train_idx % opt.freq_plot == 0:
            print(
                'Name: {0} | Epoch: {1} | {2}/{3} | Err: {4:.06f} | LR: {5:.06f} | Sigma: {6:.02f} | dataT: {7:.05f} | netT: {8:.05f} | ETA: {9:02d}:{10:02d}'.format(
                    opt.name, epoch, train_idx, len(train_data_loader), error.item(), lr, opt.sigma,
                                                                        iter_start_time - iter_data_time,
                                                                        iter_net_time - iter_start_time, int(eta // 60),
                    int(eta - 60 * (eta // 60))))

        if train_idx % opt.freq_save == 0 and train_idx != 0:
            torch.save(netG.state_dict(), '%s/netG_latest' % (opt.checkpoints_path))
            torch.save(netG.state_dict(), '%s/netG_epoch_%d' % (opt.checkpoints_path, epoch))


        iter_data_time = time.time()

    # update learning rate
    lr = adjust_learning_rate(optimizerG, epoch, lr, opt.schedule, opt.gamma)

# %%
import torch
import gdown


file_id = "1rOOKucTZlx7LskwP1Gip6v7pD1kgm_cL"
ckpt_path = "netG_checkpoint.pth"
gdown.download(f"https://drive.google.com/uc?id={file_id}", ckpt_path, quiet=False)
netG.load_state_dict(torch.load(ckpt_path, map_location=cuda))

# %%
with torch.no_grad():
    set_eval()

    if not opt.no_num_eval:
        test_losses = {}
        print('calc error (test) ...')
        test_errors = calc_error(opt, netG, cuda, test_dataset, 1)
        print('eval test MSE: {0:06f} IOU: {1:06f} prec: {2:06f} recall: {3:06f}'.format(*test_errors))
        MSE, IOU, prec, recall = test_errors
        test_losses['MSE(test)'] = MSE
        test_losses['IOU(test)'] = IOU
        test_losses['prec(test)'] = prec
        test_losses['recall(test)'] = recall

# %%
def gen_mesh_func(opt, net, cuda, data, save_path, use_octree=True):
    image_tensor = data['img'].to(device=cuda)
    calib_tensor = data['calib'].to(device=cuda)

    net.filter(image_tensor)

    # b_min = data['b_min']
    # b_max = data['b_max']
    b_min = np.array([-128, -28, -128])
    b_max = np.array([128, 228, 128])
    # try:
    save_img_path = save_path[:-4] + '.png'
    save_img_list = []
    for v in range(image_tensor.shape[0]):
        save_img = (np.transpose(image_tensor[v].detach().cpu().numpy(), (1, 2, 0)) * 0.5 + 0.5)[:, :, ::-1] * 255.0
        save_img_list.append(save_img)
    save_img = np.concatenate(save_img_list, axis=1)
    Image.fromarray(np.uint8(save_img[:,:,::-1])).save(save_img_path)

    verts, faces= reconstruction(
        net, cuda, calib_tensor, opt.resolution, b_min, b_max, use_octree=use_octree)
    verts_tensor = torch.from_numpy(verts.T).unsqueeze(0).to(device=cuda).float()
    xyz_tensor = net.projection(verts_tensor, calib_tensor[:1])
    uv = xyz_tensor[:, :2, :]
    color = index(image_tensor[:1], uv).detach().cpu().numpy()[0].T
    color = color * 0.5 + 0.5
    save_obj_mesh_with_color(save_path, verts, faces, color)

# %%
# from libsdf import create_grid, eval_grid_octree, eval_grid
def reconstruction(net, cuda, calib_tensor,
                   resolution, b_min, b_max,
                   use_octree=False, num_samples=10000, transform=None):
    '''
    Reconstruct meshes from sdf predicted by the network.
    :param net: a BasePixImpNet object. call image filter beforehead.
    :param cuda: cuda device
    :param calib_tensor: calibration tensor
    :param resolution: resolution of the grid cell
    :param b_min: bounding box corner [x_min, y_min, z_min]
    :param b_max: bounding box corner [x_max, y_max, z_max]
    :param use_octree: whether to use octree acceleration
    :param num_samples: how many points to query each gpu iteration
    :return: marching cubes results.
    '''
    # First we create a grid by resolution
    # and transforming matrix for grid coordinates to real world xyz
    coords, mat = create_grid(resolution, resolution, resolution,
                              b_min, b_max, transform=transform)

    # Then we define the lambda function for cell evaluation
    def eval_func(points):
        points = np.expand_dims(points, axis=0)
        points = np.repeat(points, net.num_views, axis=0)
        samples = torch.from_numpy(points).to(device=cuda).float()
        net.query(samples, calib_tensor)
        pred = net.get_preds()[0][0]
        return pred.detach().cpu().numpy()

    # Then we evaluate the grid
    if use_octree:
        sdf = eval_grid_octree(coords, eval_func, num_samples=num_samples)
    else:
        sdf = eval_grid(coords, eval_func, num_samples=num_samples)

    # print(sdf.shape, sdf.min(), sdf.max(), np.unique(sdf))
    # verts, faces = marching_cubes(torch.from_numpy(sdf).float().cuda(), 0.5)
    # verts = verts.cpu().numpy()
    # faces = faces.cpu().numpy()
    # print(verts.shape, faces.shape)
    # return
    # # Finally we do marching cubes
    # try:
    verts, faces, normals, values = measure.marching_cubes(sdf, 0.5)
    # print(verts.shape)
    #     # transform verts into world coordinate system
    verts = np.matmul(mat[:3, :3], verts.T) + mat[:3, 3:4]
    verts = verts.T
    # return verts, faces, normals, values
    return verts, faces
    # except:
    #     print('error cannot marching cubes')
    #     return -1

# %%
with torch.no_grad():
    if not opt.no_gen_mesh:
        print('generate mesh (test) ...')
        for gen_idx in tqdm(range(opt.num_gen_mesh_test)):
            test_data = random.choice(test_dataset)
            save_path = 'test_eval_epoch_%s.obj' % (test_data['name'])
            gen_mesh_func(opt, netG, cuda, test_data, save_path)

# %%
import trimesh

human_mesh = trimesh.load("test_eval_epoch_1.obj")

scene = trimesh.scene.Scene()
scene.add_geometry(human_mesh)
scene.show()

# %% [markdown]
# # Texture Module

# %%
opt.num_sample_inout = 0
opt.num_sample_color = 500
opt.sigma = 0.1

# %%
#load data
train_dataset = TrainDataset(opt, phase='train')
test_dataset = TrainDataset(opt, phase='test')

# create data loader
train_data_loader = DataLoader(train_dataset,
                                batch_size=opt.batch_size, shuffle=not opt.serial_batches,
                                num_workers=opt.num_threads, pin_memory=opt.pin_memory)

print('train data size: ', len(train_data_loader))

# NOTE: batch size should be 1 and use all the points for evaluation
test_data_loader = DataLoader(test_dataset,
                                batch_size=1, shuffle=False,
                                num_workers=opt.num_threads, pin_memory=opt.pin_memory)
print('test data size: ', len(test_data_loader))

# %%
#initialize texture learning network
netC = ResBlkPIFuNet(opt).to(device=cuda)


#set mode
def set_train():
    netC.train()

def set_eval():
    netC.eval()

# %%
# # load checkpoints
# color_checkpoint_path = "checkpoints/net_C"
# print('loading for net C ...', color_checkpoint_path)

# netC.load_state_dict(torch.load(color_checkpoint_path, map_location=cuda))

# %%
optimizerC = torch.optim.Adam(netC.parameters(), lr=opt.learning_rate)

# %%
# train
for epoch in range(opt.num_epoch):
    epoch_start_time = time.time()

    set_train()
    iter_data_time = time.time()

    for train_idx, train_data in enumerate(train_data_loader):
        iter_start_time = time.time()


        image_tensor = train_data['img'].to(device=cuda)
        calib_tensor = train_data['calib'].to(device=cuda)

        color_sample_tensor = train_data['color_samples'].to(device=cuda)

        image_tensor, calib_tensor = reshape_multiview_tensors(image_tensor, calib_tensor)

        rgb_tensor = train_data['rgbs'].to(device=cuda)

        with torch.no_grad():
            netG.filter(image_tensor)
        resC, error = netC.forward(image_tensor, netG.get_im_feat(), color_sample_tensor, calib_tensor, labels=rgb_tensor)




        # res, error = netG.forward(image_tensor, sample_tensor, calib_tensor,  labels=label_tensor)

        optimizerC.zero_grad()
        error.backward()
        optimizerC.step()

        iter_net_time = time.time()
        eta = ((iter_net_time - epoch_start_time) / (train_idx + 1)) * len(train_data_loader) - (
                iter_net_time - epoch_start_time)

        if train_idx % opt.freq_plot == 0:
            print(
                'Name: {0} | Epoch: {1} | {2}/{3} | Err: {4:.06f} | LR: {5:.06f} | Sigma: {6:.02f} | dataT: {7:.05f} | netT: {8:.05f} | ETA: {9:02d}:{10:02d}'.format(
                    opt.name, epoch, train_idx, len(train_data_loader), error.item(), lr, opt.sigma,
                                                                        iter_start_time - iter_data_time,
                                                                        iter_net_time - iter_start_time, int(eta // 60),
                    int(eta - 60 * (eta // 60))))

        if train_idx % opt.freq_save == 0 and train_idx != 0:
            torch.save(netC.state_dict(), '%s/netC_latest' % (opt.checkpoints_path))
            torch.save(netC.state_dict(), '%s/netC_epoch_%d' % (opt.checkpoints_path, epoch))


        iter_data_time = time.time()

    # update learning rate
    lr = adjust_learning_rate(optimizerC, epoch, lr, opt.schedule, opt.gamma)

# %%
with torch.no_grad():

    set_eval()
    test_losses = {}
    print('calc error (test) ...')
    test_color_error = calc_error_color(opt, netG, netC, cuda, test_dataset, 1)
    print('eval test | color error:', test_color_error)
    test_losses['test_color'] = test_color_error

# %%
def gen_mesh_color(opt, netG, netC, cuda, data, save_path, use_octree=True):
    image_tensor = data['img'].to(device=cuda)
    calib_tensor = data['calib'].to(device=cuda)

    netG.filter(image_tensor)
    netC.filter(image_tensor)
    netC.attach(netG.get_im_feat())

    b_min = data['b_min']
    b_max = data['b_max']
    save_img_path = save_path[:-4] + '.png'
    save_img_list = []
    for v in range(image_tensor.shape[0]):
        save_img = (np.transpose(image_tensor[v].detach().cpu().numpy(), (1, 2, 0)) * 0.5 + 0.5)[:, :, ::-1] * 255.0
        save_img_list.append(save_img)
    save_img = np.concatenate(save_img_list, axis=1)
    Image.fromarray(np.uint8(save_img[:,:,::-1])).save(save_img_path)

    verts, faces = reconstruction(
        netG, cuda, calib_tensor, opt.resolution, b_min, b_max, use_octree=use_octree)

    # Now Getting colors
    verts_tensor = torch.from_numpy(verts.T).unsqueeze(0).to(device=cuda).float()
    verts_tensor = reshape_sample_tensor(verts_tensor, opt.num_views)

    color = np.zeros(verts.shape)
    interval = opt.num_sample_color
    for i in range(len(color) // interval):
        left = i * interval
        right = i * interval + interval
        if i == len(color) // interval - 1:
            right = -1
        netC.query(verts_tensor[:, :, left:right], calib_tensor)
        rgb = netC.get_preds()[0].detach().cpu().numpy() * 0.5 + 0.5
        color[left:right] = rgb.T

    save_obj_mesh_with_color(save_path, verts, faces, color)

# %%
print('generate mesh (test) ...')
for gen_idx in tqdm(range(opt.num_gen_mesh_test)):
    test_data = random.choice(test_dataset)
    save_path = 'test_eval_epoch_%s.obj' % ( test_data['name'])
    gen_mesh_color(opt, netG, netC, cuda, test_data, save_path)

# %%
import trimesh

humanmesh = trimesh.load("test_eval_epoch_1.obj")

scene = trimesh.scene.Scene()
scene.add_geometry(humanmesh)
scene.show()
